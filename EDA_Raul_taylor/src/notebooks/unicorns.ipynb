# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %%
unicorns = pd.read_csv('../data/raw/List of Unicorn Startup Companies.csv')

# %%
unicorns.tail(20)
# Out:
#      Unnamed: 0           Company Valuation(US$ billions)  \
# 638         638   Yitu Technology                      1+
# 639         639           YunQuNa                      1+
# 640         640            Zenoti                      1+
# 641         641      Zhaogang.com                      1+
# 642         642        Zhuanzhuan                      1+
# 643         643         Zuoyebang                      1+
# 644         644  LINE MAN Wongnai                      1+
# 645         645        ReliaQuest                      1+
# 646         646              DANA                      1+
# 647         647            Deezer                       1
# 648         648          Ecovadis                       1
# 649         649           Scandit                       1
# 650         650        BlueVoyant                      1+
# 651         651           Payhawk                      1+
# 652         652           Einride                    1.44
# ...

# %%
unicorns.groupby(['Country/countries', 'Industry']).max()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\taylo\Desktop\GMR Virtual\gmrvenv\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File c:\Users\taylo\Desktop\GMR Virtual\gmrvenv\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\taylo\Desktop\GMR Virtual\gmrvenv\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
#     870 for i, group in enumerate(splitter):
# ...

# %%
unicorns.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 658 entries, 0 to 657
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               658 non-null    int64
#  1   Company                  658 non-null    object
#  2   Valuation(US$ billions)  658 non-null    object
#  3   Valuation date           658 non-null    object
#  4   Industry                 594 non-null    object
#  5   Country/countries        658 non-null    object
#  6   Founder(s)               138 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 36.1+ KB
